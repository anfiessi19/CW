# %% [markdown]
# <a href="https://colab.research.google.com/github/anfiessi19/CW/blob/main/ML_HW_02_2026_NasikanAnna_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <center>
# ### <center> Домашнє завдання №2
# ##### <center><font color='blue'> Насікан Анни </font>
# #### <center>**Знайомство з Pandas**

# %% [markdown]
# Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)" посилання

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
URL="https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
TABLE_NAME = "Коефіцієнт народжуваності в регіонах України"
data = pd.read_html(URL, match=TABLE_NAME, decimal=",", thousands=".")[0]

# %% [markdown]
# **Необхідно виконати:**

# %% [markdown]
# 1. Вивести перші рядки таблиці за допомогою методу head

# %%
# Ваш код тут

# %% [markdown]
# 2. Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
# Ваш код тут

# %% [markdown]
# 3. Замініть у таблиці значення "—" на значення NaN

# %%
# Ваш код тут

# %% [markdown]
# 4. Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
# Ваш код тут

# %% [markdown]
# 5. Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
# Ваш код тут

# %% [markdown]
# 6. Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
# Ваш код тут

# %% [markdown]
# 7. Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
# Ваш код тут

# %% [markdown]
# 8. Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
# Ваш код тут

# %% [markdown]
# 9. Отримайте список регіонів, де рівень народжуваності у 2021 році був вищим за середній по Україні

# %%
# Ваш код тут

# %% [markdown]
# 10. У якому регіоні була найвища народжуваність у 2016 році?

# %%
# Ваш код тут

# %% [markdown]
# 11. Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
# Ваш код тут
