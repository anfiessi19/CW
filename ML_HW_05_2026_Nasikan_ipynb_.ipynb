# %% [markdown]
# <a href="https://colab.research.google.com/github/anfiessi19/CW/blob/main/ML_HW_05_2026_Nasikan_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <center>
# ### <center>Домашнє завдання №5
# ##### <center><font color='blue'>Насікан Анни </font>
# #### <center>**Розв'язання задачі класифікації. Метрики оцінки якості класифікації**

# %% [markdown]
# Датасет kaggle, Credit Card Fraud Detection: https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# ### <center> Виявлення шахрайства з кредитними картками

# %% [markdown]
# Набір даних містить транзакції, здійснені за кредитними картками у вересні 2013 року власниками карток з Європи.
# Цей набір даних представляє транзакції, які сталися за два дні, де ми маємо 492 шахрайства з 284 807 транзакцій. Набір даних дуже незбалансований, на позитивний клас (шахрайство) припадає 0,172% всіх транзакцій.
#
# Він містить лише числові вхідні змінні, що є результатом перетворення PCA. На жаль, з міркувань конфіденційності ми не можемо надати вихідні функції та додаткову довідкову інформацію про дані. Ознаки V1, V2, … V28 є основними компонентами, отриманими за допомогою PCA, єдині ознаки, які не були перетворені за допомогою PCA, – це 'Time' та 'Amount'. Ознака 'Time' містить секунди, що пройшли між кожною транзакцією та першою транзакцією у наборі даних. Ознака 'Amount' - це сума транзакції. Ознака «Клас» — це змінна відповіді, яка набуває значення 1 у разі шахрайства та 0 в іншому випадку.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %matplotlib inline

# %% [markdown]
# **1. Завантажити датасет**

# %%
data = pd.read_csv('creditcard.csv')
data.head()

# %%
data.shape

# %% [markdown]
# **2. Подивитися відсутні значення (яка кількість Nan елементів)**

# %%
data.isna().sum()

# %%
data.info()

# %% [markdown]
# **3. Значення цільової мітки: 1 – угода була обманною, 0 – чесною. Побудуємо графік barplot для цих двох класів із колонки 'Class'. Порахуємо кількість елементів у кожному класі**

# %%
a = data['Class'].value_counts()
a

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.barplot(x=a.index, y=a)

# %% [markdown]
# **4. Скільки грошей було використано в обманних операціях, а скільки – у звичайних операціях?**

# %%
data.groupby('Class')['Amount'].sum()

# %% [markdown]
# **5. Побудувати матрицю кореляцій для всіх значень**

# %%
data.corr().style.background_gradient(cmap='coolwarm')

# %% [markdown]
# **6. Розділити дані на тренувальні та тестові**

# %%
y = data['Class']
X = data.drop('Class', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# ### **Будемо навчати наступні моделі: дерево рішень, kNN, логістичну регресію та метод опорних векторів**

# %% [markdown]
# **7. Для методу найближчих сусідів виконайте вибір параметрів за допомогою GridSearchCV**

# %% [markdown]
# **8. Оцініть якість за допомогою метрик accuracy, precision, recall_score, f1, побудуйте ROC криву та виведіть значення roc_auc_score**

# %% [markdown]
# **9. Для методу дерева рішення виконайте підбір параметрів за допомогою GridSearchCV**

# %% [markdown]
# **10. Оцініть якість за допомогою метрик accuracy, precision, recall_score, f1, побудуйте ROC криву та виведіть значення roc_auc_score**

# %% [markdown]
# **11. Для логістичної регресії виконайте вибір параметрів за допомогою GridSearchCV**

# %% [markdown]
# **12. Оцініть якість за допомогою метрик accuracy, precision, recall_score, f1, побудуйте ROC криву та виведіть значення roc_auc_score**

# %% [markdown]
# **13. Для методу опорних векторів виконайте вибір параметрів за допомогою GridSearchCV**

# %% [markdown]
# **14. Оцініть якість за допомогою метрик accuracy, precision, recall_score, f1, побудуйте ROC криву та виведіть значення roc_auc_score**

# %% [markdown]
# **15. Напишіть висновок, яка модель краща**

# %% [markdown]
# **16. Застосуйте один із методів роботи з незбалансованими вибірками (downsample або upsample, використовуючи sklearn.utils.resample). Оберіть найкращу за попередніми результатами модель та заново навчіть її на нових (перетворених) даних з підбором параметрів за допомогою GridSearchCV**

# %% [markdown]
# **17. Оцініть якість за допомогою метрик accuracy, f1 та виведіть значення roc_auc_score**

# %% [markdown]
# **18. Застосуйте метод SMOTE для роботи з незбалансованими даними. Оберіть найкращу за попередніми результатами модель та заново навчіть її на нових (перетворених) даних з підбором параметрів за допомогою GridSearchCV**

# %% [markdown]
# **19. Оцініть якість за допомогою метрик accuracy, f1 та виведіть значення roc_auc_score**
